# %% [markdown]
# # <center> Working with XML Files </center>

# %%
import pandas as pd

# %%
pd.set_option('display.max_column',None)
# pd.set_option('display.colheader_justify', 'center') // this only works on printing dataframe using PRINT function

# %%
url = "https://gist.githubusercontent.com/jonm/3080489/raw/282155349da23b26c69ec64c559f90e1b60ee7f4/gistfile1.txt"
# To read the nested XMl data, we need to flatten the data. This is done using XML stylesheet(XSL)
xsl_style_string = '''<?xml version="1.0" encoding="UTF-8"?>
<xsl:stylesheet
    xmlns:xsl="http://www.w3.org/1999/XSL/Transform"
    xmlns:xs="http://www.w3.org/2001/XMLSchema"
    exclude-result-prefixes="xs" version="2.0">

    <xsl:output method="xml" indent="yes"/>

    <xsl:template match="@* | node()">
        <xsl:copy>
            <xsl:apply-templates select="@* | node()"/>
        </xsl:copy>
    </xsl:template>

    <xsl:template match="user">
        <xsl:for-each select="*">
            <xsl:element name="{concat(name(..),'_',name())}">
                <xsl:apply-templates select="node()"/>
            </xsl:element>
        </xsl:for-each>
    </xsl:template>

</xsl:stylesheet>'''
df1_xml = pd.read_xml(url,stylesheet=xsl_style_string)
# df1_xml.style.set_properties(**{'text-align': 'center'}) --> to align the data of the dataframe
#To align the column names of the DataFrame in center
df1_xml.style.set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
# Out:
# <style type="text/css">
# #T_74f5e th {
#   text-align: center;
# }
# </style>
# <table id="T_74f5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74f5e_level0_col0" class="col_heading level0 col0" >created_at</th>
#       <th id="T_74f5e_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_74f5e_level0_col2" class="col_heading level0 col2" >text</th>
#       <th id="T_74f5e_level0_col3" class="col_heading level0 col3" >source</th>
#       <th id="T_74f5e_level0_col4" class="col_heading level0 col4" >truncated</th>
#       <th id="T_74f5e_level0_col5" class="col_heading level0 col5" >in_reply_to_status_id</th>
#       <th id="T_74f5e_level0_col6" class="col_heading level0 col6" >in_reply_to_user_id</th>
#       <th id="T_74f5e_level0_col7" class="col_heading level0 col7" >in_reply_to_screen_name</th>
#       <th id="T_74f5e_level0_col8" class="col_heading level0 col8" >possibly_sensitive</th>
# ...

# %%
df1_xml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 54 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   created_at                               19 non-null     object
#  1   id                                       19 non-null     int64
#  2   text                                     19 non-null     object
#  3   source                                   19 non-null     object
#  4   truncated                                19 non-null     bool
#  5   in_reply_to_status_id                    3 non-null      float64
#  6   in_reply_to_user_id                      3 non-null      float64
#  7   in_reply_to_screen_name                  3 non-null      object
#  8   possibly_sensitive                       8 non-null      object
#  9   user_id                                  19 non-null     int64
# ...

# %%
# Converting created_at and user_created_at columns to datetime format
df1_xml['created_at'] = pd.to_datetime(df1_xml['created_at'],infer_datetime_format=True)
df1_xml['user_created_at'] = pd.to_datetime(df1_xml['user_created_at'],infer_datetime_format=True)
df1_xml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 54 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   created_at                               19 non-null     datetime64[ns, UTC]
#  1   id                                       19 non-null     int64
#  2   text                                     19 non-null     object
#  3   source                                   19 non-null     object
#  4   truncated                                19 non-null     bool
#  5   in_reply_to_status_id                    3 non-null      float64
#  6   in_reply_to_user_id                      3 non-null      float64
#  7   in_reply_to_screen_name                  3 non-null      object
#  8   possibly_sensitive                       8 non-null      object
#  9   user_id                                  19 non-null     int64
# ...
